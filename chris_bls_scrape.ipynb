# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
url = 'https://www.bls.gov/news.release/laus.t01.htm'
tables = pd.read_html(url)

# %%
unemployment_df = tables[0].iloc[:-2,[0,9]]
unemployment_df.columns = ['state','unempl_June_18']
unemployment_df
# Out:
#                                       state unempl_June_18
# 0                                   Alabama            4.1
# 1                                    Alaska            6.6
# 2                                   Arizona            4.7
# 3                                  Arkansas            3.7
# 4                                California            4.2
# 5        Los Angeles-Long Beach-Glendale(1)            4.6
# 6                                  Colorado            3.2
# 7                               Connecticut            4.1
# 8                                  Delaware            3.8
# 9                      District of Columbia            5.6
# 10                                  Florida            3.6
# 11             Miami-Miami Beach-Kendall(1)            3.7
# 12                                  Georgia            3.9
# 13                                   Hawaii            2.4
# 14                                    Idaho            2.8
# ...

# %%
# Mohamed is doing this
# url = 'https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations'
# table = pd.read_html(url)
# zip_df = table[0].iloc[:,[0,3]]
# zip_df.columns = ['state','abbr']
# zip_df = zip_df.dropna()
# df = pd.merge(unemployment_df,zip_df,how ='inner',on='state')

# %%
engine = create_engine('postgresql://postgres:Douglas11@localhost/etl_project')
conn = engine.connect()

# %%
unemployment_df.to_sql('unemployment', con=engine,if_exists='replace',index=False)

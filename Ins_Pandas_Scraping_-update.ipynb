# %% [markdown]
# # Scraping with Pandas

# %%
import pandas as pd
from cm_password import username,password

# %%
GDP_State_2018 = 'https://en.wikipedia.org/wiki/List_of_U.S._states_by_GDP_per_capita'
State_Abreviation = 'http://www.softschools.com/social_studies/state_abbreviations/'
#State_Abreviation = 'https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations'

# %%
GDP = pd.read_html(GDP_State_2018)
State_Abreviation = pd.read_html(State_Abreviation)
#GDP[0].head(5)

# %%
df = State_Abreviation[2]
df.head(5)
# Out:
#         State Abbreviation
# 0     ALABAMA           AL
# 1      ALASKA           AK
# 2     ARIZONA           AZ
# 3    ARKANSAS           AR
# 4  CALIFORNIA           CA

# %% [markdown]
# We can slice off any of those dataframes that we want using normal indexing.

# %%
GDP = pd.read_html(GDP_State_2018)
GDP=pd.DataFrame(GDP[0])
GDP=GDP[['State', '2018']]
GDP
# Out:
#                    State    2018
# 0   District of Columbia  160472
# 1          Massachusetts   65545
# 2               New York   64579
# 3            Connecticut   64511
# 4                 Alaska   63971
# 5               Delaware   63664
# 6           North Dakota   62837
# 7                Wyoming   58821
# 8             New Jersey   57084
# 9             Washington   56831
# 10              Maryland   55404
# 11              Illinois   54091
# 12            California   53987
# 13                 Texas   53795
# 14             Minnesota   53704
# 15              Nebraska   53114
# 16              Colorado   52795
# 17         New Hampshire   51794
# 18              Virginia   51736
# 19                Hawaii   51277
# 20          Pennsylvania   50997
# 21                Oregon   50582
# 22         United States   50577
# 23                  Iowa   50315
# 24          South Dakota   48076
# 25          Rhode Island   47639
# 26                  Ohio   47567
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/etl_project')

# %%
GDP.to_sql('GDP', con=engine,if_exists='replace',index=False)

# %%
df.to_sql('State_Abreviation', con=engine,if_exists='replace',index=False)
